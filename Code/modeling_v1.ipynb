# %%
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import ecopy as ep

# %%
input_data = pd.read_csv('/home/llevin/Desktop/capstone2/cleaned_data/input_data_vF2.csv')

# %%
def dist_gower(datamtx, strict=True):
    """returns a row-row gower dist matrix
    
    see for example, Faith et al., 1987
    
    
    * note that the comparison between any two rows is dependent on the entire
    data matrix, d_ij is a fn of all of datamtx, not just i,j
    * comparisons are between rows (samples)
    * any column containing identical data for all rows is ignored (this
    prevents a 0/0 error in the formula for gower distance
    * input: 2D numpy array.  Limited support for non-2D arrays if 
    strict==False
    * output: numpy 2D array float ('d') type.  shape (inputrows, inputrows)
    for sane input data
    * two rows of all zeros returns 0 distance between them
    * if strict==True, raises ValueError if any of the input data is
    not finite, or if the input data is not a rank 2 array (a matrix).
    * if strict==False, assumes input data is a 2d matrix.  
    If rank of input data is < 2, returns an empty 2d array (shape:
    (0, 0) ).  If 0 rows or 0 colunms, also returns an empty 2d array.
    """
    if strict:
        if not np.isfinite(datamtx).any():
            raise ValueError("non finite number in input matrix")
        if np.ndim(datamtx) != 2:
            raise ValueError("input matrix not 2D")
        numrows, numcols = np.shape(datamtx)
    else:
        try:
            numrows, numcols = np.shape(datamtx)
        except ValueError:
            return np.zeros((0,0),'d')
    if numrows == 0 or numcols == 0:
        return np.zeros((0,0),'d')
    dists = np.zeros((numrows,numrows),'d')
    coldiffs = datamtx.max(axis=0) - datamtx.min(axis=0)
    for i in range(numcols):
        if coldiffs[i] == 0.0:
            coldiffs[i] = 1.0 # numerator will be zero anyway
    for i in range(numrows):
        r1 = datamtx[i]
        for j in range(i):
            r2 = datamtx[j]
            rowdiff = r2 - r1
            dist = sum(abs(r1 - r2) / coldiffs)
            dists[i,j] = dists[j,i] = dist

    return dists

# %%
num_cols = input_data.select_dtypes(include=['int64','float64']).columns
num_cols = [col for col in num_cols if col not in ['home_team_api_id','away_team_api_id','result']]
X = input_data[num_cols].values
X.shape
# Out:
# (902, 97)

# %%
scale = StandardScaler()

norm_data = scale.fit_transform(X)

# %%
X_gower = dist_gower(norm_data)

# %%
norm_data
# Out:
# array([[-0.63162026,  2.27752825, -1.53313494, ..., -0.11111111,
#         -0.17898775, -0.1255618 ],
#        [ 0.09832397, -0.24656381, -0.27195143, ..., -0.11111111,
#         -0.17898775, -0.1255618 ],
#        [-0.26664815,  1.7166189 , -0.27195143, ..., -0.11111111,
#         -0.17898775, -0.1255618 ],
#        ...,
#        [ 0.09832397, -1.64883717,  0.56883757, ..., -0.11111111,
#         -0.17898775, -0.1255618 ],
#        [ 0.82826821, -1.92929185,  0.77903482, ..., -0.11111111,
#         -0.17898775, -0.1255618 ],
#        [-1.3615645 , -0.52701848, -1.32293769, ..., -0.11111111,
#         -0.17898775, -0.1255618 ]])

# %%
X_gower
# Out:
# array([[  0.        ,  13.86936993,  14.28157725, ...,  15.97415305,
#          21.48005184,  15.20866514],
#        [ 13.86936993,   0.        ,  12.97425243, ...,  12.99448479,
#          14.74668601,  15.27299494],
#        [ 14.28157725,  12.97425243,   0.        , ...,  13.89881453,
#          16.38711021,  18.7381474 ],
#        ...,
#        [ 15.97415305,  12.99448479,  13.89881453, ...,   0.        ,
#          12.39525836,  13.86546378],
#        [ 21.48005184,  14.74668601,  16.38711021, ...,  12.39525836,
#           0.        ,  19.4987074 ],
#        [ 15.20866514,  15.27299494,  18.7381474 , ...,  13.86546378,
#          19.4987074 ,   0.        ]])

# %%
X_gower.shape
# Out:
# (902, 902)

# %%
X_gower.mean(), X_gower.max(), X_gower.min()
# Out:
# (14.742523884733441, 28.382698153217625, 0.0)

# %%
db = DBSCAN(eps=11,min_samples=2,metric='precomputed').fit(X_gower)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

print('Estimated number of clusters: %d' % n_clusters_)
print("Silhouette Coefficient: %0.3f" % metrics.silhouette_score(norm_data, labels))
# Out:
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.170

# %%
# import matplotlib.pyplot as plt

# # Black removed and is used for noise instead.
# unique_labels = set(labels)
# colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels)))
# for k, col in zip(unique_labels, colors):
#     if k == -1:
#         # Black used for noise.
#         col = 'k'

#     class_member_mask = (labels == k)

#     xy = X[class_member_mask & core_samples_mask]
#     plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
#              markeredgecolor='k', markersize=14)

#     xy = X[class_member_mask & ~core_samples_mask]
#     plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
#              markeredgecolor='k', markersize=6)

# plt.title('Estimated number of clusters: %d' % n_clusters_)
# plt.show()

# %%
def dbscan_gower(X,eps=range(1,20),min_samples=range(1,10)):
    for i in eps:
        for j in min_samples:
            try:
                db = DBSCAN(eps=i,min_samples=j,metric='precomputed').fit(X)
                labels = db.labels_
                n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
                print 'Eps: %d' % i
                print 'Min_Samples: %d' % j
                print('Estimated number of clusters: %d' % n_clusters_)
                print("Silhouette Coefficient: %0.3f" % metrics.silhouette_score(norm_data, labels))
            except:
                pass

# %%
dbscan_gower(X_gower)
# Out:
# Eps: 1
# Min_Samples: 1
# Estimated number of clusters: 902
# Eps: 1
# Min_Samples: 2
# Estimated number of clusters: 0
# Eps: 1
# Min_Samples: 3
# Estimated number of clusters: 0
# Eps: 1
# Min_Samples: 4
# Estimated number of clusters: 0
# Eps: 1
# Min_Samples: 5
# Estimated number of clusters: 0
# Eps: 1
# Min_Samples: 6
# Estimated number of clusters: 0
# Eps: 1
# Min_Samples: 7
# Estimated number of clusters: 0
# Eps: 1
# Min_Samples: 8
# Estimated number of clusters: 0
# Eps: 1
# Min_Samples: 9
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 1
# Estimated number of clusters: 902
# Eps: 2
# Min_Samples: 2
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 3
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 4
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 5
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 6
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 7
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 8
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 9
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 1
# Estimated number of clusters: 902
# Eps: 3
# Min_Samples: 2
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 3
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 4
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 5
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 6
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 7
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 8
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 9
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 1
# Estimated number of clusters: 902
# Eps: 4
# Min_Samples: 2
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 3
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 4
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 5
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 6
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 7
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 8
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 9
# Estimated number of clusters: 0
# Eps: 5
# Min_Samples: 1
# Estimated number of clusters: 902
# Eps: 5
# Min_Samples: 2
# Estimated number of clusters: 0
# Eps: 5
# Min_Samples: 3
# Estimated number of clusters: 0
# Eps: 5
# Min_Samples: 4
# Estimated number of clusters: 0
# Eps: 5
# Min_Samples: 5
# Estimated number of clusters: 0
# Eps: 5
# Min_Samples: 6
# Estimated number of clusters: 0
# Eps: 5
# Min_Samples: 7
# Estimated number of clusters: 0
# Eps: 5
# Min_Samples: 8
# Estimated number of clusters: 0
# Eps: 5
# Min_Samples: 9
# Estimated number of clusters: 0
# Eps: 6
# Min_Samples: 1
# Estimated number of clusters: 883
# Silhouette Coefficient: 0.965
# Eps: 6
# Min_Samples: 2
# Estimated number of clusters: 18
# Silhouette Coefficient: -0.202
# Eps: 6
# Min_Samples: 3
# Estimated number of clusters: 1
# Silhouette Coefficient: -0.105
# Eps: 6
# Min_Samples: 4
# Estimated number of clusters: 0
# Eps: 6
# Min_Samples: 5
# Estimated number of clusters: 0
# Eps: 6
# Min_Samples: 6
# Estimated number of clusters: 0
# Eps: 6
# Min_Samples: 7
# Estimated number of clusters: 0
# Eps: 6
# Min_Samples: 8
# Estimated number of clusters: 0
# Eps: 6
# Min_Samples: 9
# Estimated number of clusters: 0
# Eps: 7
# Min_Samples: 1
# Estimated number of clusters: 766
# Silhouette Coefficient: 0.787
# Eps: 7
# Min_Samples: 2
# Estimated number of clusters: 63
# Silhouette Coefficient: -0.178
# Eps: 7
# Min_Samples: 3
# Estimated number of clusters: 25
# Silhouette Coefficient: -0.162
# Eps: 7
# Min_Samples: 4
# Estimated number of clusters: 14
# Silhouette Coefficient: -0.158
# Eps: 7
# Min_Samples: 5
# Estimated number of clusters: 4
# Silhouette Coefficient: -0.116
# Eps: 7
# Min_Samples: 6
# Estimated number of clusters: 1
# Silhouette Coefficient: -0.092
# Eps: 7
# Min_Samples: 7
# Estimated number of clusters: 0
# Eps: 7
# Min_Samples: 8
# Estimated number of clusters: 0
# Eps: 7
# Min_Samples: 9
# Estimated number of clusters: 0
# Eps: 8
# Min_Samples: 1
# Estimated number of clusters: 441
# Silhouette Coefficient: 0.374
# Eps: 8
# Min_Samples: 2
# Estimated number of clusters: 59
# Silhouette Coefficient: -0.092
# Eps: 8
# Min_Samples: 3
# Estimated number of clusters: 34
# Silhouette Coefficient: -0.077
# Eps: 8
# Min_Samples: 4
# Estimated number of clusters: 27
# Silhouette Coefficient: -0.092
# Eps: 8
# Min_Samples: 5
# Estimated number of clusters: 23
# Silhouette Coefficient: -0.098
# Eps: 8
# Min_Samples: 6
# Estimated number of clusters: 21
# Silhouette Coefficient: -0.101
# Eps: 8
# Min_Samples: 7
# Estimated number of clusters: 16
# Silhouette Coefficient: -0.109
# Eps: 8
# Min_Samples: 8
# Estimated number of clusters: 11
# Silhouette Coefficient: -0.108
# Eps: 8
# Min_Samples: 9
# Estimated number of clusters: 8
# Silhouette Coefficient: -0.108
# Eps: 9
# Min_Samples: 1
# Estimated number of clusters: 133
# Silhouette Coefficient: -0.025
# Eps: 9
# Min_Samples: 2
# Estimated number of clusters: 6
# Silhouette Coefficient: -0.041
# Eps: 9
# Min_Samples: 3
# Estimated number of clusters: 2
# Silhouette Coefficient: -0.025
# Eps: 9
# Min_Samples: 4
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.066
# Eps: 9
# Min_Samples: 5
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.065
# Eps: 9
# Min_Samples: 6
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.057
# Eps: 9
# Min_Samples: 7
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.003
# Eps: 9
# Min_Samples: 8
# Estimated number of clusters: 3
# Silhouette Coefficient: -0.033
# Eps: 9
# Min_Samples: 9
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.008
# Eps: 10
# Min_Samples: 1
# Estimated number of clusters: 20
# Silhouette Coefficient: -0.019
# Eps: 10
# Min_Samples: 2
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.126
# Eps: 10
# Min_Samples: 3
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.126
# Eps: 10
# Min_Samples: 4
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.130
# Eps: 10
# Min_Samples: 5
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.142
# Eps: 10
# Min_Samples: 6
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.144
# Eps: 10
# Min_Samples: 7
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.139
# Eps: 10
# Min_Samples: 8
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.126
# Eps: 10
# Min_Samples: 9
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.125
# Eps: 11
# Min_Samples: 1
# Estimated number of clusters: 7
# Silhouette Coefficient: 0.061
# Eps: 11
# Min_Samples: 2
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.170
# Eps: 11
# Min_Samples: 3
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.170
# Eps: 11
# Min_Samples: 4
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.170
# Eps: 11
# Min_Samples: 5
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.193
# Eps: 11
# Min_Samples: 6
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.193
# Eps: 11
# Min_Samples: 7
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.193
# Eps: 11
# Min_Samples: 8
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.193
# Eps: 11
# Min_Samples: 9
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.193
# Eps: 12
# Min_Samples: 1
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.190
# Eps: 12
# Min_Samples: 2
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.190
# Eps: 12
# Min_Samples: 3
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.190
# Eps: 12
# Min_Samples: 4
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.190
# Eps: 12
# Min_Samples: 5
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.190
# Eps: 12
# Min_Samples: 6
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.190
# Eps: 12
# Min_Samples: 7
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.190
# Eps: 12
# Min_Samples: 8
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.179
# Eps: 12
# Min_Samples: 9
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.179
# Eps: 13
# Min_Samples: 1
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 2
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 3
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 4
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 5
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 6
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 7
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 8
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 9
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 1
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 2
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 3
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 4
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 5
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 6
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 7
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 8
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 9
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 1
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 2
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 3
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 4
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 5
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 6
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 7
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 8
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 9
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 1
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 2
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 3
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 4
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 5
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 6
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 7
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 8
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 9
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 1
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 2
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 3
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 4
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 5
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 6
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 7
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 8
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 9
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 1
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 2
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 3
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 4
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 5
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 6
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 7
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 8
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 9
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 1
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 2
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 3
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 4
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 5
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 6
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 7
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 8
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 9
# Estimated number of clusters: 1

# %%
def apply_clusters(df,cols,eps,min_samples):
    X = df[cols].values
    scale = StandardScaler()
    norm_data = scale.fit_transform(X)
    X_gower = dist_gower(norm_data)
    db = DBSCAN(eps=eps,min_samples=min_samples,metric='precomputed').fit(X_gower)
    labels = db.labels_
    clusters = []
    n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
    print set(labels)
    print('Estimated number of clusters: %d' % n_clusters_)
    for i in labels:
        if i == -1:
            clusters.append('noise')
        else:
            clusters.append(str(i))
    df['cluster'] = clusters
    cluster_group = df.groupby('cluster').mean().reset_index()
    return cluster_group.T

# %%
apply_clusters(input_data,num_cols,11,2)
# Out:
# set([0, 1, -1])
# Estimated number of clusters: 2
#                                  0        1        2
# cluster                          0        1    noise
# away_corners               4.71669        9      3.8
# away_fouls                 10.8891     12.5      7.8
# away_shots                 11.2576     13.5       16
# away_shots_target           4.8757      9.5      8.2
# away_yellow_cards          1.79843        3      1.4
# away_red_cards            0.100784        0      0.4
# full_time_away_goals       1.16125     1.75      2.2
# full_time_home_goals        1.6047        1      1.8
# home_corners               6.17581     7.25     10.6
# home_fouls                 10.5913     9.75       12
# home_red_cards           0.0582307     0.25      0.6
# home_yellow_cards          1.41433     1.75      2.4
# home_shots                 14.7503    14.25     22.6
# home_shots_target          6.35722     6.75     12.8
# half_time_away_goals      0.522956     0.75        1
# half_time_home_goals      0.716685     0.25      0.8
# half_time_result           1.45913      0.5      1.4
# result                     1.66181      0.5      1.4
# Capacity                   39015.4    18439  32580.4
# home_team_api_id            9264.1    10172   9027.4
# away_team_api_id           9211.55  9409.75   9245.2
# home_possession            51.9127    50.25     59.6
# home_passing               78.8193     73.8    81.18
# home_aerials               16.5802       11     14.2
# home_shots_against         13.4225     16.5    14.68
# home_tackles               19.1704     20.1    17.96
# home_interceptions         14.9702     14.4    14.86
# home_dribbles              8.00347      5.9     7.48
# home_fouls_for             10.5381     11.7    10.52
# ...                            ...      ...      ...
# away_shotoff_volleys      0.275476     0.75      0.6
# away_shotoff_other         3.22956     4.25        4
# away_shotoff_bigchance    0.418813     1.25      0.8
# away_shotoff_bad_shot       0.3729     0.25      0.6
# home_crosses                 21.29    21.25     33.8
# away_crosses               16.1265    18.25     18.8
# at_Emirates Stadium      0.0582307        0        0
# at_Boleyn Ground         0.0425532        0        0
# at_Loftus Road           0.0335946        1        0
# at_Britannia Stadium     0.0548712        0        0
# at_The Hawthorns         0.0548712        0        0
# at_Anfield               0.0515118        0        0
# at_Sports Direct Arena    0.055991        0        0
# at_Turf Moor             0.0145577        0        0
# at_Villa Park            0.0526316        0        0
# at_Goodison Park         0.0571109        0        0
# at_St Mary's Stadium     0.0414334        0        0
# at_Liberty Stadium       0.0503919        0      0.2
# at_Etihad Stadium         0.055991        0      0.2
# at_Stamford Bridge       0.0582307        0      0.2
# at_King Power Stadium    0.0134378        0        0
# at_KC Stadium            0.0246361        0        0
# at_Old Trafford          0.0537514        0        0
# at_Stadium of Light      0.0481523        0        0
# at_Selhurst Park         0.0279955        0        0
# at_White Hart Lane       0.0526316        0        0
# at_Carrow Road           0.0403135        0        0
# at_Cardiff City Stadium  0.0111982        0      0.2
# at_Craven Cottage        0.0302352        0      0.2
# at_Madejski Stadium      0.0156775        0        0
#
# [101 rows x 3 columns]

# %%
input_data['Stadium'].value_counts()
# Out:
# Stamford Bridge          53
# Emirates Stadium         52
# Etihad Stadium           51
# Goodison Park            51
# Sports Direct Arena      50
# The Hawthorns            49
# Britannia Stadium        49
# Old Trafford             48
# Villa Park               47
# White Hart Lane          47
# Anfield                  46
# Liberty Stadium          46
# Stadium of Light         43
# Boleyn Ground            38
# St Mary's Stadium        37
# Carrow Road              36
# Loftus Road              34
# Craven Cottage           28
# Selhurst Park            25
# KC Stadium               22
# Madejski Stadium         14
# Turf Moor                13
# King Power Stadium       12
# Cardiff City Stadium     11
# Name: Stadium, dtype: int64
