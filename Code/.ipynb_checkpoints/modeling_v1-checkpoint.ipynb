# %%
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import ecopy as ep

# %%
input_data = pd.read_csv('/home/llevin/Desktop/capstone2/cleaned_data/input_data_vF2.csv')

# %%
def dist_gower(datamtx, strict=True):
    """returns a row-row gower dist matrix
    
    see for example, Faith et al., 1987
    
    
    * note that the comparison between any two rows is dependent on the entire
    data matrix, d_ij is a fn of all of datamtx, not just i,j
    * comparisons are between rows (samples)
    * any column containing identical data for all rows is ignored (this
    prevents a 0/0 error in the formula for gower distance
    * input: 2D numpy array.  Limited support for non-2D arrays if 
    strict==False
    * output: numpy 2D array float ('d') type.  shape (inputrows, inputrows)
    for sane input data
    * two rows of all zeros returns 0 distance between them
    * if strict==True, raises ValueError if any of the input data is
    not finite, or if the input data is not a rank 2 array (a matrix).
    * if strict==False, assumes input data is a 2d matrix.  
    If rank of input data is < 2, returns an empty 2d array (shape:
    (0, 0) ).  If 0 rows or 0 colunms, also returns an empty 2d array.
    """
    if strict:
        if not np.isfinite(datamtx).any():
            raise ValueError("non finite number in input matrix")
        if np.ndim(datamtx) != 2:
            raise ValueError("input matrix not 2D")
        numrows, numcols = np.shape(datamtx)
    else:
        try:
            numrows, numcols = np.shape(datamtx)
        except ValueError:
            return np.zeros((0,0),'d')
    if numrows == 0 or numcols == 0:
        return np.zeros((0,0),'d')
    dists = np.zeros((numrows,numrows),'d')
    coldiffs = datamtx.max(axis=0) - datamtx.min(axis=0)
    for i in range(numcols):
        if coldiffs[i] == 0.0:
            coldiffs[i] = 1.0 # numerator will be zero anyway
    for i in range(numrows):
        r1 = datamtx[i]
        for j in range(i):
            r2 = datamtx[j]
            rowdiff = r2 - r1
            dist = sum(abs(r1 - r2) / coldiffs)
            dists[i,j] = dists[j,i] = dist

    return dists

# %%
for col in input_data.columns:
    print col
# Out:
# away_corners
# away_fouls
# away_shots
# away_shots_target
# away_yellow_cards
# away_red_cards
# away_team
# full_time_away_goals
# full_time_home_goals
# home_corners
# home_fouls
# home_red_cards
# home_yellow_cards
# home_shots
# home_shots_target
# half_time_away_goals
# half_time_home_goals
# half_time_result
# home_team
# Referee
# result
# City
# Stadium
# Capacity
# Country
# season
# date
# home_team_api_id
# away_team_api_id
# home_possession
# home_passing
# home_aerials
# home_shots_against
# home_tackles
# home_interceptions
# home_dribbles
# home_fouls_for
# away_possession
# away_passing
# away_aerials
# away_shots_against
# away_tackles
# away_interceptions
# away_dribbles
# away_fouls_for
# temp (F)
# dew (F)
# humidity
# wind direction
# wind speed (mph)
# prec (in)
# visibility (mi)
# home_goal_headers
# home_goal_freekicks
# home_goal_volleys
# home_goal_other
# away_goal_headers
# away_goal_freekicks
# away_goal_volleys
# away_goal_other
# home_shoton_headers
# home_shoton_freekicks
# home_shoton_volleys
# home_shoton_other
# home_shoton_bigchance
# away_shoton_headers
# away_shoton_freekicks
# away_shoton_volleys
# away_shoton_other
# away_shoton_bigchance
# home_shotoff_headers
# home_shotoff_freekicks
# home_shotoff_volleys
# home_shotoff_other
# home_shotoff_bigchance
# home_shotoff_bad_shot
# away_shotoff_headers
# away_shotoff_freekicks
# away_shotoff_volleys
# away_shotoff_other
# away_shotoff_bigchance
# away_shotoff_bad_shot
# home_crosses
# away_crosses
# at_Emirates Stadium
# at_Boleyn Ground
# at_Loftus Road
# at_Britannia Stadium
# at_The Hawthorns
# at_Anfield
# at_Sports Direct Arena
# at_Turf Moor
# at_Villa Park
# at_Goodison Park
# at_St Mary's Stadium
# at_Liberty Stadium
# at_Etihad Stadium
# at_Stamford Bridge
# at_King Power Stadium
# at_KC Stadium
# at_Old Trafford
# at_Stadium of Light
# at_Selhurst Park
# at_White Hart Lane
# at_Carrow Road
# at_Cardiff City Stadium
# at_Craven Cottage
# at_Madejski Stadium

# %%
num_cols = input_data.select_dtypes(include=['int64','float64']).columns
num_cols = [col for col in num_cols if col not in ['home_team_api_id','away_team_api_id','result','prec (in)',
                                                  'full_time_home_goals','full_time_away_goals','at_Emirates Stadium',
                                                   'at_Boleyn Ground','at_Loftus Road','at_Britannia Stadium',
                                                   'at_The Hawthorns','at_Anfield','at_Sports Direct Arena',
                                                   'at_Turf Moor','at_Villa Park','at_Goodison Park',
                                                   "at_St Mary's Stadium",'at_Liberty Stadium','at_Etihad Stadium',
                                                   'at_Stamford Bridge','at_King Power Stadium','at_KC Stadium',
                                                   'at_Old Trafford','at_Stadium of Light','at_Selhurst Park',
                                                   'at_White Hart Lane','at_Carrow Road','at_Cardiff City Stadium',
                                                   'at_Craven Cottage','at_Madejski Stadium']]
X = input_data[num_cols].values
X.shape
# Out:
# (902, 94)

# %%
scale = StandardScaler()

norm_data = scale.fit_transform(X)

# %%
X_gower = dist_gower(norm_data)

# %%
X_gower.shape
# Out:
# (902, 902)

# %%
X_gower.mean(), X_gower.max(), X_gower.min()
# Out:
# (14.356295244428486, 27.799364819884293, 0.0)

# %%
db = DBSCAN(eps=11,min_samples=2,metric='precomputed').fit(X_gower)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

print('Estimated number of clusters: %d' % n_clusters_)
print("Silhouette Coefficient: %0.3f" % metrics.silhouette_score(norm_data, labels))
# Out:
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.170

# %%
def dbscan_gower(X,eps=range(1,20),min_samples=range(1,10)):
    X_gower = dist_gower(X)
    for i in eps:
        for j in min_samples:
            db = DBSCAN(eps=i,min_samples=j,metric='precomputed').fit(X_gower)
            labels = db.labels_
            try:
                n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
                print 'Eps: %d' % i
                print 'Min_Samples: %d' % j
                print('Estimated number of clusters: %d' % n_clusters_)
                print("Silhouette Coefficient: %0.3f" % metrics.silhouette_score(norm_data, labels))
            except:
                pass

# %%
dbscan_gower(norm_data)
# Out:
# Eps: 1
# Min_Samples: 1
# Estimated number of clusters: 902
# Eps: 1
# Min_Samples: 2
# Estimated number of clusters: 0
# Eps: 1
# Min_Samples: 3
# Estimated number of clusters: 0
# Eps: 1
# Min_Samples: 4
# Estimated number of clusters: 0
# Eps: 1
# Min_Samples: 5
# Estimated number of clusters: 0
# Eps: 1
# Min_Samples: 6
# Estimated number of clusters: 0
# Eps: 1
# Min_Samples: 7
# Estimated number of clusters: 0
# Eps: 1
# Min_Samples: 8
# Estimated number of clusters: 0
# Eps: 1
# Min_Samples: 9
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 1
# Estimated number of clusters: 902
# Eps: 2
# Min_Samples: 2
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 3
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 4
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 5
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 6
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 7
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 8
# Estimated number of clusters: 0
# Eps: 2
# Min_Samples: 9
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 1
# Estimated number of clusters: 902
# Eps: 3
# Min_Samples: 2
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 3
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 4
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 5
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 6
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 7
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 8
# Estimated number of clusters: 0
# Eps: 3
# Min_Samples: 9
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 1
# Estimated number of clusters: 902
# Eps: 4
# Min_Samples: 2
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 3
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 4
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 5
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 6
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 7
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 8
# Estimated number of clusters: 0
# Eps: 4
# Min_Samples: 9
# Estimated number of clusters: 0
# Eps: 5
# Min_Samples: 1
# Estimated number of clusters: 901
# Silhouette Coefficient: 0.998
# Eps: 5
# Min_Samples: 2
# Estimated number of clusters: 1
# Silhouette Coefficient: -0.063
# Eps: 5
# Min_Samples: 3
# Estimated number of clusters: 0
# Eps: 5
# Min_Samples: 4
# Estimated number of clusters: 0
# Eps: 5
# Min_Samples: 5
# Estimated number of clusters: 0
# Eps: 5
# Min_Samples: 6
# Estimated number of clusters: 0
# Eps: 5
# Min_Samples: 7
# Estimated number of clusters: 0
# Eps: 5
# Min_Samples: 8
# Estimated number of clusters: 0
# Eps: 5
# Min_Samples: 9
# Estimated number of clusters: 0
# Eps: 6
# Min_Samples: 1
# Estimated number of clusters: 870
# Silhouette Coefficient: 0.945
# Eps: 6
# Min_Samples: 2
# Estimated number of clusters: 25
# Silhouette Coefficient: -0.210
# Eps: 6
# Min_Samples: 3
# Estimated number of clusters: 6
# Silhouette Coefficient: -0.148
# Eps: 6
# Min_Samples: 4
# Estimated number of clusters: 1
# Silhouette Coefficient: -0.103
# Eps: 6
# Min_Samples: 5
# Estimated number of clusters: 0
# Eps: 6
# Min_Samples: 6
# Estimated number of clusters: 0
# Eps: 6
# Min_Samples: 7
# Estimated number of clusters: 0
# Eps: 6
# Min_Samples: 8
# Estimated number of clusters: 0
# Eps: 6
# Min_Samples: 9
# Estimated number of clusters: 0
# Eps: 7
# Min_Samples: 1
# Estimated number of clusters: 729
# Silhouette Coefficient: 0.738
# Eps: 7
# Min_Samples: 2
# Estimated number of clusters: 69
# Silhouette Coefficient: -0.167
# Eps: 7
# Min_Samples: 3
# Estimated number of clusters: 31
# Silhouette Coefficient: -0.153
# Eps: 7
# Min_Samples: 4
# Estimated number of clusters: 19
# Silhouette Coefficient: -0.155
# Eps: 7
# Min_Samples: 5
# Estimated number of clusters: 9
# Silhouette Coefficient: -0.138
# Eps: 7
# Min_Samples: 6
# Estimated number of clusters: 4
# Silhouette Coefficient: -0.132
# Eps: 7
# Min_Samples: 7
# Estimated number of clusters: 1
# Silhouette Coefficient: -0.067
# Eps: 7
# Min_Samples: 8
# Estimated number of clusters: 0
# Eps: 7
# Min_Samples: 9
# Estimated number of clusters: 0
# Eps: 8
# Min_Samples: 1
# Estimated number of clusters: 345
# Silhouette Coefficient: 0.258
# Eps: 8
# Min_Samples: 2
# Estimated number of clusters: 45
# Silhouette Coefficient: -0.074
# Eps: 8
# Min_Samples: 3
# Estimated number of clusters: 26
# Silhouette Coefficient: -0.052
# Eps: 8
# Min_Samples: 4
# Estimated number of clusters: 24
# Silhouette Coefficient: -0.054
# Eps: 8
# Min_Samples: 5
# Estimated number of clusters: 20
# Silhouette Coefficient: -0.062
# Eps: 8
# Min_Samples: 6
# Estimated number of clusters: 22
# Silhouette Coefficient: -0.083
# Eps: 8
# Min_Samples: 7
# Estimated number of clusters: 17
# Silhouette Coefficient: -0.085
# Eps: 8
# Min_Samples: 8
# Estimated number of clusters: 12
# Silhouette Coefficient: -0.087
# Eps: 8
# Min_Samples: 9
# Estimated number of clusters: 12
# Silhouette Coefficient: -0.095
# Eps: 9
# Min_Samples: 1
# Estimated number of clusters: 71
# Silhouette Coefficient: -0.064
# Eps: 9
# Min_Samples: 2
# Estimated number of clusters: 6
# Silhouette Coefficient: 0.001
# Eps: 9
# Min_Samples: 3
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.086
# Eps: 9
# Min_Samples: 4
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.090
# Eps: 9
# Min_Samples: 5
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.029
# Eps: 9
# Min_Samples: 6
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.078
# Eps: 9
# Min_Samples: 7
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.077
# Eps: 9
# Min_Samples: 8
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.071
# Eps: 9
# Min_Samples: 9
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.066
# Eps: 10
# Min_Samples: 1
# Estimated number of clusters: 14
# Silhouette Coefficient: 0.020
# Eps: 10
# Min_Samples: 2
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.151
# Eps: 10
# Min_Samples: 3
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.151
# Eps: 10
# Min_Samples: 4
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.151
# Eps: 10
# Min_Samples: 5
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.171
# Eps: 10
# Min_Samples: 6
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.172
# Eps: 10
# Min_Samples: 7
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.172
# Eps: 10
# Min_Samples: 8
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.166
# Eps: 10
# Min_Samples: 9
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.160
# Eps: 11
# Min_Samples: 1
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.172
# Eps: 11
# Min_Samples: 2
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.230
# Eps: 11
# Min_Samples: 3
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.230
# Eps: 11
# Min_Samples: 4
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.230
# Eps: 11
# Min_Samples: 5
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.230
# Eps: 11
# Min_Samples: 6
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.225
# Eps: 11
# Min_Samples: 7
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.225
# Eps: 11
# Min_Samples: 8
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.225
# Eps: 11
# Min_Samples: 9
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.225
# Eps: 12
# Min_Samples: 1
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.191
# Eps: 12
# Min_Samples: 2
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.191
# Eps: 12
# Min_Samples: 3
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.191
# Eps: 12
# Min_Samples: 4
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.191
# Eps: 12
# Min_Samples: 5
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.191
# Eps: 12
# Min_Samples: 6
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.191
# Eps: 12
# Min_Samples: 7
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.191
# Eps: 12
# Min_Samples: 8
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.191
# Eps: 12
# Min_Samples: 9
# Estimated number of clusters: 1
# Silhouette Coefficient: 0.191
# Eps: 13
# Min_Samples: 1
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 2
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 3
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 4
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 5
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 6
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 7
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 8
# Estimated number of clusters: 1
# Eps: 13
# Min_Samples: 9
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 1
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 2
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 3
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 4
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 5
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 6
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 7
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 8
# Estimated number of clusters: 1
# Eps: 14
# Min_Samples: 9
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 1
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 2
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 3
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 4
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 5
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 6
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 7
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 8
# Estimated number of clusters: 1
# Eps: 15
# Min_Samples: 9
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 1
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 2
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 3
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 4
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 5
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 6
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 7
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 8
# Estimated number of clusters: 1
# Eps: 16
# Min_Samples: 9
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 1
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 2
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 3
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 4
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 5
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 6
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 7
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 8
# Estimated number of clusters: 1
# Eps: 17
# Min_Samples: 9
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 1
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 2
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 3
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 4
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 5
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 6
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 7
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 8
# Estimated number of clusters: 1
# Eps: 18
# Min_Samples: 9
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 1
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 2
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 3
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 4
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 5
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 6
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 7
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 8
# Estimated number of clusters: 1
# Eps: 19
# Min_Samples: 9
# Estimated number of clusters: 1

# %%
def apply_clusters(df,cols,eps,min_samples):
    X = df[cols].values
    scale = StandardScaler()
    norm_data = scale.fit_transform(X)
    X_gower = dist_gower(norm_data)
    db = DBSCAN(eps=eps,min_samples=min_samples,metric='precomputed').fit(X_gower)
    labels = db.labels_
    clusters = []
    n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
    print set(labels)
    print('Estimated number of clusters: %d' % n_clusters_)
    for i in labels:
        if i == -1:
            clusters.append('noise')
        else:
            clusters.append(str(i))
    df['cluster'] = clusters
    cluster_group = df.groupby('cluster').mean().reset_index()
    return cluster_group.T

# %%
apply_clusters(input_data,num_cols,10,2)
# Out:
# set([0, 1, -1])
# Estimated number of clusters: 2
#                                  0        1          2
# cluster                          0        1      noise
# away_corners               4.72009        9    4.08333
# away_fouls                 10.8646     12.5    11.4167
# away_shots                 11.2675     13.5       12.5
# away_shots_target          4.87923      9.5          6
# away_yellow_cards          1.78668        3        2.5
# away_red_cards           0.0981941        0   0.416667
# full_time_away_goals       1.16366     1.75    1.41667
# full_time_home_goals       1.60609        1    1.58333
# home_corners               6.17043     7.25    8.41667
# home_fouls                 10.5914     9.75    11.1667
# home_red_cards           0.0586907     0.25       0.25
# home_yellow_cards          1.41761     1.75    1.58333
# home_shots                 14.7325    14.25    19.3333
# home_shots_target           6.3544     6.75       9.25
# half_time_away_goals      0.523702     0.75   0.666667
# half_time_home_goals      0.717833     0.25   0.666667
# half_time_result            1.4605      0.5    1.33333
# result                     1.65914      0.5       1.75
# Capacity                   38999.6    18439    37502.6
# home_team_api_id           9257.15    10172    9678.67
# away_team_api_id           9209.26  9409.75    9394.75
# home_possession            51.8634    50.25      58.75
# home_passing               78.8054     73.8     80.825
# home_aerials               16.6062       11    13.6667
# home_shots_against          13.415     16.5       14.5
# home_tackles               19.1691     20.1    18.7667
# home_interceptions         14.9604     14.4      15.65
# home_dribbles               8.0053      5.9       7.65
# home_fouls_for             10.5351     11.7      10.75
# ...                            ...      ...        ...
# away_shotoff_volleys      0.268623     0.75   0.916667
# away_shotoff_other         3.22799     4.25    3.66667
# away_shotoff_bigchance    0.414221     1.25   0.916667
# away_shotoff_bad_shot     0.374718     0.25   0.333333
# home_crosses               21.2788    21.25    27.3333
# away_crosses               16.1038    18.25    18.9167
# at_Emirates Stadium      0.0586907        0          0
# at_Boleyn Ground         0.0428894        0          0
# at_Loftus Road           0.0316027        1   0.166667
# at_Britannia Stadium     0.0553047        0          0
# at_The Hawthorns         0.0553047        0          0
# at_Anfield               0.0519187        0          0
# at_Sports Direct Arena   0.0553047        0  0.0833333
# at_Turf Moor             0.0146727        0          0
# at_Villa Park            0.0530474        0          0
# at_Goodison Park         0.0575621        0          0
# at_St Mary's Stadium     0.0417607        0          0
# at_Liberty Stadium       0.0496614        0   0.166667
# at_Etihad Stadium        0.0564334        0  0.0833333
# at_Stamford Bridge       0.0586907        0  0.0833333
# at_King Power Stadium     0.013544        0          0
# at_KC Stadium            0.0248307        0          0
# at_Old Trafford          0.0519187        0   0.166667
# at_Stadium of Light      0.0485327        0          0
# at_Selhurst Park         0.0282167        0          0
# at_White Hart Lane       0.0530474        0          0
# at_Carrow Road           0.0406321        0          0
# at_Cardiff City Stadium  0.0112867        0  0.0833333
# at_Craven Cottage        0.0293454        0   0.166667
# at_Madejski Stadium      0.0158014        0          0
#
# [101 rows x 3 columns]

# %%
input_data['Stadium'].value_counts()
# Out:
# Stamford Bridge          53
# Emirates Stadium         52
# Etihad Stadium           51
# Goodison Park            51
# Sports Direct Arena      50
# The Hawthorns            49
# Britannia Stadium        49
# Old Trafford             48
# Villa Park               47
# White Hart Lane          47
# Anfield                  46
# Liberty Stadium          46
# Stadium of Light         43
# Boleyn Ground            38
# St Mary's Stadium        37
# Carrow Road              36
# Loftus Road              34
# Craven Cottage           28
# Selhurst Park            25
# KC Stadium               22
# Madejski Stadium         14
# Turf Moor                13
# King Power Stadium       12
# Cardiff City Stadium     11
# Name: Stadium, dtype: int64
