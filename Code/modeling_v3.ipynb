# %%
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import ecopy as ep
from sklearn.decomposition import PCA

# %%
input_data = pd.read_csv('/home/llevin/Desktop/capstone2/cleaned_data/input_data_vF3.csv')

# %%
def dist_gower(datamtx, strict=True):
    """returns a row-row gower dist matrix
    
    see for example, Faith et al., 1987
    
    
    * note that the comparison between any two rows is dependent on the entire
    data matrix, d_ij is a fn of all of datamtx, not just i,j
    * comparisons are between rows (samples)
    * any column containing identical data for all rows is ignored (this
    prevents a 0/0 error in the formula for gower distance
    * input: 2D numpy array.  Limited support for non-2D arrays if 
    strict==False
    * output: numpy 2D array float ('d') type.  shape (inputrows, inputrows)
    for sane input data
    * two rows of all zeros returns 0 distance between them
    * if strict==True, raises ValueError if any of the input data is
    not finite, or if the input data is not a rank 2 array (a matrix).
    * if strict==False, assumes input data is a 2d matrix.  
    If rank of input data is < 2, returns an empty 2d array (shape:
    (0, 0) ).  If 0 rows or 0 colunms, also returns an empty 2d array.
    """
    if strict:
        if not np.isfinite(datamtx).any():
            raise ValueError("non finite number in input matrix")
        if np.ndim(datamtx) != 2:
            raise ValueError("input matrix not 2D")
        numrows, numcols = np.shape(datamtx)
    else:
        try:
            numrows, numcols = np.shape(datamtx)
        except ValueError:
            return np.zeros((0,0),'d')
    if numrows == 0 or numcols == 0:
        return np.zeros((0,0),'d')
    dists = np.zeros((numrows,numrows),'d')
    coldiffs = datamtx.max(axis=0) - datamtx.min(axis=0)
    for i in range(numcols):
        if coldiffs[i] == 0.0:
            coldiffs[i] = 1.0 # numerator will be zero anyway
    for i in range(numrows):
        r1 = datamtx[i]
        for j in range(i):
            r2 = datamtx[j]
            rowdiff = r2 - r1
            dist = sum(abs(r1 - r2) / coldiffs)
            dists[i,j] = dists[j,i] = dist

    return dists

# %%
input_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1626 entries, 0 to 1625
# Data columns (total 88 columns):
# away_corners               1626 non-null int64
# away_fouls                 1626 non-null int64
# away_shots                 1626 non-null int64
# away_shots_target          1626 non-null int64
# away_yellow_cards          1626 non-null int64
# away_red_cards             1626 non-null int64
# away_team                  1626 non-null object
# full_time_away_goals       1626 non-null int64
# full_time_home_goals       1626 non-null int64
# home_corners               1626 non-null int64
# home_fouls                 1626 non-null int64
# home_red_cards             1626 non-null int64
# home_yellow_cards          1626 non-null int64
# home_shots                 1626 non-null int64
# home_shots_target          1626 non-null int64
# half_time_away_goals       1626 non-null int64
# half_time_home_goals       1626 non-null int64
# half_time_result           1626 non-null int64
# home_team                  1626 non-null object
# Referee                    1267 non-null object
# result                     1626 non-null int64
# City                       1626 non-null object
# Stadium                    1626 non-null object
# Capacity                   1626 non-null float64
# Country                    1626 non-null object
# season                     1626 non-null object
# date                       1626 non-null object
# home_team_api_id           1626 non-null int64
# away_team_api_id           1626 non-null int64
# temp (F)                   1626 non-null float64
# dew (F)                    1626 non-null float64
# humidity                   1626 non-null float64
# wind direction             1626 non-null float64
# wind speed (mph)           1626 non-null float64
# visibility (mi)            1626 non-null float64
# home_goal_headers          1626 non-null int64
# home_goal_freekicks        1626 non-null int64
# home_goal_volleys          1626 non-null int64
# home_goal_other            1626 non-null int64
# away_goal_headers          1626 non-null int64
# away_goal_freekicks        1626 non-null int64
# away_goal_volleys          1626 non-null int64
# away_goal_other            1626 non-null int64
# home_shoton_headers        1626 non-null int64
# home_shoton_freekicks      1626 non-null int64
# home_shoton_volleys        1626 non-null int64
# home_shoton_other          1626 non-null int64
# home_shoton_bigchance      1626 non-null int64
# away_shoton_headers        1626 non-null int64
# away_shoton_freekicks      1626 non-null int64
# away_shoton_volleys        1626 non-null int64
# away_shoton_other          1626 non-null int64
# away_shoton_bigchance      1626 non-null int64
# away_shotoff_headers       1626 non-null int64
# away_shotoff_freekicks     1626 non-null int64
# away_shotoff_volleys       1626 non-null int64
# away_shotoff_other         1626 non-null int64
# away_shotoff_bigchance     1626 non-null int64
# away_shotoff_bad_shot      1626 non-null int64
# home_crosses               1626 non-null int64
# away_crosses               1626 non-null int64
# home_possession            1626 non-null int64
# away_possession            1626 non-null int64
# at_Emirates Stadium        1626 non-null int64
# at_Boleyn Ground           1626 non-null int64
# at_King Power Stadium      1626 non-null int64
# at_Old Trafford            1626 non-null int64
# at_Loftus Road             1626 non-null int64
# at_Britannia Stadium       1626 non-null int64
# at_The Hawthorns           1626 non-null int64
# at_Anfield                 1626 non-null int64
# at_Sports Direct Arena     1626 non-null int64
# at_Turf Moor               1626 non-null int64
# at_Villa Park              1626 non-null int64
# at_Stamford Bridge         1626 non-null int64
# at_Selhurst Park           1626 non-null int64
# at_Goodison Park           1626 non-null int64
# at_St Mary's Stadium       1626 non-null int64
# at_Liberty Stadium         1626 non-null int64
# at_KC Stadium              1626 non-null int64
# at_Stadium of Light        1626 non-null int64
# at_White Hart Lane         1626 non-null int64
# at_Etihad Stadium          1626 non-null int64
# at_Carrow Road             1626 non-null int64
# at_Craven Cottage          1626 non-null int64
# at_Cardiff City Stadium    1626 non-null int64
# at_Madejski Stadium        1626 non-null int64
# at_Molineux Stadium        1626 non-null int64
# dtypes: float64(7), int64(73), object(8)
# memory usage: 1.1+ MB

# %%
num_cols = input_data.select_dtypes(include=['int64','float64']).columns
num_cols = [col for col in num_cols if col not in ['result','full_time_home_goals','full_time_away_goals',
                                                   'half_time_home_goals','half_time_away_goals','half_time_results'
                                                   ,'at_Emirates Stadium','at_Boleyn Ground','at_King Power Stadium'
                                                   ,'at_Old Trafford','at_Loftus Road','at_Britannia Stadium'
                                                   ,'at_The Hawthorns','at_Anfield','at_Sports Direct Arena'
                                                   ,'at_Turf Moor','at_Villa Park','at_Stamford Bridge','at_Selhurst Park'
                                                   ,'at_Goodison Park',"at_St Mary's Stadium",'at_Liberty Stadium',
                                                   'at_KC Stadium','at_Stadium of Light','at_White Hart Lane'
                                                   ,'at_Etihad Stadium','at_Carrow Road','at_Molineux Stadium',
                                                   'at_Cardiff City Stadium','at_Craven Cottage','at_Madejski Stadium']]
pca_cols = [col for col in num_cols if col not in ['home_team_api_id','away_team_api_id']]
X = input_data[pca_cols].values
X.shape
# Out:
# (1626, 48)

# %%
scale = StandardScaler()

norm_data = scale.fit_transform(X)
norm_data.shape
# Out:
# (1626, 2)

# %%
soccer_pca = PCA()
soccer_pca.fit(norm_data)
# soccer_pcs = pca.transform(norm_data)
# soccer_pcs = pd.DataFrame(soccer_pcs,columns=['PC'+str(i) for i in range(1, soccer_pcs.shape[1]+1)])
# soccer_pcs.head()

# %%
def dbscan_gower(df,eps=range(1,20),min_samples=range(1,10)):
    scale = StandardScaler()
    clusters_info = []
    for n in range(len(pca_cols)):
        columns = pca_cols[n:n+4]
        X = input_data[columns].values
        X_n = scale.fit_transform(X)
        X_gower = dist_gower(X_n)
        for i in eps:
            for j in min_samples:
                db = DBSCAN(eps=i,min_samples=j,metric='euclidean').fit(X_n)
                labels = db.labels_
                try:
                    n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
                    if n_clusters_>1 and i>1 and j>1:
                        clusters_info.append([n,i,j,n_clusters_,metrics.silhouette_score(X_n, labels)])
                except:
                    pass
    clusters_info = sorted(clusters_info,reverse=True,key=lambda x: x[4])
    max_sil = clusters_info[0]
    print 'Column Index: ', max_sil[0]
    print 'Max Distance: ', max_sil[1]
    print 'Min Samples: ', max_sil[2]
    print 'Number of Clusters: ', max_sil[3]
    print 'Silhouette Score: ', max_sil[4]

# %%
dbscan_gower(input_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-65b0fb2da3a3> in <module>()
# ----> 1 dbscan_gower(input_data)
#
# <ipython-input-73-5171e15b9594> in dbscan_gower(df, eps, min_samples)
#       9         for i in eps:
#      10             for j in min_samples:
# ---> 11                 db = DBSCAN(eps=i,min_samples=j,metric='euclidean').fit(X_n)
#      12                 labels = db.labels_
#      13                 try:
#
# /home/llevin/anaconda2/envs/dsi/lib/python2.7/site-packages/sklearn/cluster/dbscan_.pyc in fit(self, X, y, sample_weight)
#     263         """
#     264         X = check_array(X, accept_sparse='csr')
# --> 265         clust = dbscan(X, sample_weight=sample_weight, **self.get_params())
#     266         self.core_sample_indices_, self.labels_ = clust
#     267         if len(self.core_sample_indices_):
#
# /home/llevin/anaconda2/envs/dsi/lib/python2.7/site-packages/sklearn/cluster/dbscan_.pyc in dbscan(X, eps, min_samples, metric, algorithm, leaf_size, p, sample_weight, random_state)
#     144         # This has worst case O(n^2) memory complexity
#     145         neighborhoods = neighbors_model.radius_neighbors(X, eps,
# --> 146                                                          return_distance=False)
#     147
#     148     if sample_weight is None:
#
# /home/llevin/anaconda2/envs/dsi/lib/python2.7/site-packages/sklearn/neighbors/base.pyc in radius_neighbors(self, X, radius, return_distance)
#     636                     "or set algorithm='brute'" % self._fit_method)
#     637             results = self._tree.query_radius(X, radius,
# --> 638                                               return_distance=return_distance)
#     639             if return_distance:
#     640                 results = results[::-1]
#
# KeyboardInterrupt:

# %%
def dbscan_gower(df,eps=range(1,20),min_samples=range(1,10)):
    scale = StandardScaler()
    clusters_info = []
    X = input_data[pca_cols].values
    X_n = scale.fit_transform(X)
    for i in eps:
        for j in min_samples:
            db = DBSCAN(eps=i,min_samples=j,metric='euclidean').fit(X_n)
            labels = db.labels_
            try:
                n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
                if n_clusters_>1 and i>1 and j>1:
                    clusters_info.append([i,j,n_clusters_,metrics.silhouette_score(X_n, labels)])
            except:
                pass
    clusters_info = sorted(clusters_info,reverse=True,key=lambda x: x[3])
    max_sil = clusters_info[0]
    print 'Max Distance: ', max_sil[0]
    print 'Min Samples: ', max_sil[1]
    print 'Number of Clusters: ', max_sil[2]
    print 'Silhouette Score: ', max_sil[3]

dbscan_gower(input_data)
# Out:
# Max Distance:  8
# Min Samples:  6
# Number of Clusters:  2
# Silhouette Score:  0.275857949339

# %%
def apply_clusters(df,cols,eps,min_samples):
    X = df[cols].values
    scale = StandardScaler()
    norm_data = scale.fit_transform(X)
    X_gower = dist_gower(norm_data)
    db = DBSCAN(eps=eps,min_samples=min_samples,metric='euclidean').fit(norm_data)
    labels = db.labels_
    clusters = []
    n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
    print set(labels)
    print('Estimated number of clusters: %d' % n_clusters_)
    for i in labels:
        if i == -1:
            clusters.append('noise')
        else:
            clusters.append(str(i))
    df['cluster'] = clusters
    print df['cluster'].value_counts()
    cluster_group = df.groupby('cluster').mean().reset_index()
    return cluster_group.T

# %%
pca_cols[16:20]
# Out:
# ['humidity', 'wind direction', 'wind speed (mph)', 'visibility (mi)']

# %%
pd.set_option('display.max_rows', len(input_data))
cluster = apply_clusters(input_data,pca_cols,8,6)
# Out:
# set([0, 1, -1])
# Estimated number of clusters: 2
# 0        1583
# noise      35
# 1           8
# Name: cluster, dtype: int64

# %%
cluster
# Out:
#                                   0        1          2
# cluster                           0        1      noise
# away_corners                4.66709        5    6.28571
# away_fouls                  11.0891       11    11.8857
# away_shots                  11.0739   13.125    14.9429
# away_shots_target           4.91661      7.5    8.14286
# away_yellow_cards           1.81807    2.125    2.31429
# away_red_cards            0.0947568        0   0.257143
# full_time_away_goals        1.09602    0.875          2
# full_time_home_goals        1.60139     1.75    1.62857
# home_corners                6.34491    5.625    5.94286
# home_fouls                  10.4839        9    11.1429
# home_red_cards            0.0536955    0.125   0.314286
# home_yellow_cards           1.40998    1.625    1.57143
# home_shots                  14.8939   13.875    16.5429
# home_shots_target           6.72963     7.75    9.02857
# half_time_away_goals       0.482628      0.5   0.885714
# half_time_home_goals       0.718256    1.125   0.542857
# half_time_result              1.506    1.625          1
# result                      1.69488    1.375    1.31429
# Capacity                    39461.2  22069.5    36146.5
# home_team_api_id             9195.9  10025.5    9462.14
# away_team_api_id             9195.1  9158.38    9218.17
# temp (F)                    47.5721        0    38.5653
# dew (F)                     40.9996        0    33.2523
# humidity                    78.6406        0    63.3424
# wind direction               190.01        0    146.498
# wind speed (mph)            10.0358        0    8.05608
# visibility (mi)             5.72985        0     4.8038
# home_goal_headers          0.268478     0.25        0.4
# home_goal_freekicks       0.0486418        0   0.114286
# home_goal_volleys         0.0751737    0.125   0.228571
# home_goal_other             1.07644    1.375   0.828571
# away_goal_headers           0.18067    0.125   0.514286
# away_goal_freekicks       0.0277953        0   0.114286
# away_goal_volleys         0.0518004        0   0.371429
# away_goal_other            0.766267     0.75   0.685714
# home_shoton_headers        0.711308     0.25   0.885714
# home_shoton_freekicks      0.209728    0.125   0.542857
# home_shoton_volleys        0.145925        0        0.4
# home_shoton_other           5.80417        6    6.94286
# home_shoton_bigchance      0.628553      0.5    1.37143
# away_shoton_headers        0.526848     1.25        0.6
# away_shoton_freekicks      0.154769    0.125   0.371429
# away_shoton_volleys         0.11813        0   0.371429
# away_shoton_other            4.3765        6        6.2
# away_shoton_bigchance      0.479469    0.625        0.8
# away_shotoff_headers       0.869236    1.375   0.828571
# away_shotoff_freekicks     0.217309        0   0.285714
# away_shotoff_volleys       0.269109     0.25   0.514286
# away_shotoff_other          3.33607    3.625    4.08571
# away_shotoff_bigchance     0.380922     0.25   0.828571
# away_shotoff_bad_shot       0.33228     0.75   0.514286
# home_crosses                21.6008    21.25       23.4
# away_crosses                16.0891    19.25       18.2
# home_possession             52.2426    50.75    49.0286
# away_possession             47.7574    49.25    50.9714
# at_Emirates Stadium       0.0827543        0          0
# at_Boleyn Ground            0.07012        0  0.0857143
# at_King Power Stadium     0.0120025        0          0
# at_Old Trafford           0.0454833        0  0.0857143
# at_Loftus Road            0.0277953      0.5   0.171429
# at_Britannia Stadium      0.0448515        0  0.0571429
# at_The Hawthorns          0.0467467        0          0
# at_Anfield                 0.046115        0  0.0285714
# at_Sports Direct Arena     0.046115        0          0
# at_Turf Moor              0.0120025        0          0
# at_Villa Park             0.0448515        0  0.0571429
# at_Stamford Bridge        0.0808591        0   0.142857
# at_Selhurst Park          0.0227416        0  0.0285714
# at_Goodison Park           0.046115        0          0
# at_St Mary's Stadium      0.0360076        0          0
# at_Liberty Stadium        0.0435881        0  0.0285714
# at_KC Stadium             0.0227416        0  0.0285714
# at_Stadium of Light       0.0448515        0  0.0857143
# at_White Hart Lane        0.0827543        0          0
# at_Etihad Stadium         0.0454833        0  0.0285714
# at_Carrow Road            0.0334807        0  0.0571429
# at_Craven Cottage         0.0290587      0.5   0.114286
# at_Cardiff City Stadium   0.0120025        0          0
# at_Madejski Stadium       0.0120025        0          0
# at_Molineux Stadium      0.00947568        0          0

# %%
cluster[0]=cluster[0].map(lambda x: float(x))
cluster[1]=cluster[1].map(lambda x: float(x))
cluster['01_delta'] = (cluster[0]-cluster[1])/cluster[0]

# %%
cluster['01_delta']
# Out:
# cluster                         -inf
# away_corners               -0.401267
# away_fouls                  0.009779
# away_shots                 -0.262620
# away_shots_target          -0.724562
# away_yellow_cards          -0.132747
# away_red_cards             -0.465878
# full_time_away_goals       -0.219385
# full_time_home_goals        0.109009
# home_corners                0.121248
# home_fouls                  0.143338
# home_red_cards             -1.422556
# home_yellow_cards          -0.060799
# home_shots                 -0.000371
# home_shots_target          -0.180977
# half_time_away_goals       -0.458446
# half_time_home_goals        0.104115
# half_time_result            0.285566
# result                      0.238218
# Capacity                    0.440793
# home_team_api_id           -0.089954
# away_team_api_id           -0.017575
# temp (F)                    0.996088
# dew (F)                     0.995903
# humidity                    0.995267
# wind direction              0.994123
# wind speed (mph)            0.997189
# visibility (mi)             0.995609
# home_goal_headers          -0.058128
# home_goal_freekicks         1.000000
# home_goal_volleys          -0.826531
# home_goal_other             0.135301
# away_goal_headers          -1.309126
# away_goal_freekicks         1.000000
# away_goal_volleys           1.000000
# away_goal_other            -0.121736
# home_shoton_headers         0.199503
# home_shoton_freekicks       0.672161
# home_shoton_volleys         0.048996
# home_shoton_other          -0.066611
# home_shoton_bigchance       0.225481
# away_shoton_headers        -0.482185
# away_shoton_freekicks      -0.348493
# away_shoton_volleys         1.000000
# away_shoton_other          -0.507698
# away_shoton_bigchance      -0.620724
# away_shotoff_headers       -0.066996
# away_shotoff_freekicks      0.674019
# away_shotoff_volleys       -0.572730
# away_shotoff_other         -0.367355
# away_shotoff_bigchance     -1.220028
# away_shotoff_bad_shot      -0.698471
# home_crosses                0.082938
# away_crosses               -0.218273
# home_possession             0.072115
# away_possession            -0.078729
# at_Emirates Stadium         1.000000
# at_Boleyn Ground            1.000000
# at_King Power Stadium       1.000000
# at_Old Trafford             1.000000
# at_Loftus Road            -16.138298
# at_Britannia Stadium        1.000000
# at_The Hawthorns            1.000000
# at_Anfield                  1.000000
# at_Sports Direct Arena      1.000000
# at_Turf Moor                1.000000
# at_Villa Park               1.000000
# at_Stamford Bridge          1.000000
# at_Selhurst Park            1.000000
# at_Goodison Park            1.000000
# at_St Mary's Stadium        1.000000
# at_Liberty Stadium          1.000000
# at_KC Stadium               1.000000
# at_Stadium of Light         1.000000
# at_White Hart Lane          1.000000
# at_Etihad Stadium           1.000000
# at_Carrow Road              1.000000
# at_Craven Cottage         -16.138298
# at_Cardiff City Stadium     1.000000
# at_Madejski Stadium         1.000000
# at_Molineux Stadium         1.000000
# Name: 01_delta, dtype: float64
